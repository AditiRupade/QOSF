# %%
# importing necessary packages
import qiskit
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit import Aer, execute
import math
import random
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

# %%
# define some random vectors
random1 = random.sample(range(0,20),16)    
random2 = random.sample(range(0,20),16)
random3 = random.sample(range(0,20),16)
random4 = random.sample(range(0,20),16)

print(random1, random2, random3, random4)
# Out:
# [17, 7, 19, 10, 4, 6, 13, 3, 12, 2, 11, 8, 0, 5, 18, 15] [2, 6, 17, 12, 10, 16, 3, 0, 7, 19, 5, 4, 1, 15, 8, 13] [16, 6, 1, 9, 10, 11, 13, 19, 4, 15, 12, 0, 5, 17, 14, 2] [11, 12, 6, 0, 2, 15, 18, 14, 9, 7, 10, 3, 1, 5, 17, 8]

# %%
# compute how many qubits needed to encode
nqubits = math.ceil(np.log2(16))
print("qubit needed to encode the vectors-", nqubits)
# Out:
# qubit needed to encode the vectors- 4

# %%
# normalise vectors
random1_norm = np.linalg.norm(random1) 
random2_norm = np.linalg.norm(random2) 
random3_norm = np.linalg.norm(random3) 
random4_norm = np.linalg.norm(random4) 

random1 = random1/random1_norm
random2 = random2/random2_norm
random3 = random3/random3_norm
random4 = random4/random4_norm

# %%
# create circuit
circ = QuantumCircuit(nqubits+2)   
vec = np.concatenate((random1,random2,random3,random4))/np.sqrt(4)    # concatenate vectotrs

circ.initialize(vec, range(nqubits+2))
circ.h(nqubits)                   

circ.draw()
# Out:
#      »
# q_0: »
#      »
# q_1: »
#      »
# q_2: »
#      »
# q_3: »
#      »
# q_4: »
#      »
# q_5: »
#      »
# «     ┌───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐»
# «q_0: ┤0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ├»
# «     │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │»
# «q_1: ┤1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ├»
# «     │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │»
# «q_2: ┤2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ├»
# «     │  Initialize(0.19318,0.079545,0.21591,0.11364,0.045455,0.068182,0.14773,0.034091,0.13636,0.022727,0.125,0.090909,0,0.056818,0.20455,0.17045,0.023918,0.071755,0.20331,0.14351,0.11959,0.19135,0.035877,0,0.083714,0.22722,0.059796,0.047836,0.011959,0.17939,0.095673,0.15547,0.17782,0.066683,0.011114,0.10002,0.11114,0.12225,0.14448,0.21116,0.044455,0.16671,0.13337,0,0.055569,0.18894,0.15559,0.022228,0.13467,0.14691,3/13π,0,1/13π,0.18364,0.22037,0.1714,0.11018,0.085698,0.12243,0.036728,0.012243,0.061213,0.20812,0.09794) │»
# «q_3: ┤3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ├»
# «     │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │»
# «q_4: ┤4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ├»
# «     │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │»
# «q_5: ┤5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ├»
# «     └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘»
# «
# «q_0: ─────
# «
# «q_1: ─────
# «
# «q_2: ─────
# «
# «q_3: ─────
# «     ┌───┐
# «q_4: ┤ H ├
# «     └───┘
# «q_5: ─────
# «

# %%
nlayers=2
